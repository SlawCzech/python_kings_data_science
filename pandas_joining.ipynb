# %%
import os

import pandas as pd
from pandas.errors import MergeError

# %%
master = pd.read_pickle(os.path.join('dataset01', 'master-pickle'))
scoring = pd.read_pickle(os.path.join('dataset01', 'scoring.pickle'))
teams = pd.read_pickle(os.path.join('dataset01', 'teams.pickle'))
team_splits = pd.read_pickle(os.path.join('dataset01', 'team_splits.pickle'))

# %%
master.head(2)
# Out:
#           firstName    lastName pos  birthYear  birthMon  birthDay  \
# playerID
# aaltoan01     Antti       Aalto   C     1975.0       3.0       4.0
# abdelju01    Justin  Abdelkader   L     1987.0       2.0      25.0
#
#           birthCountry birthState     birthCity
# playerID
# aaltoan01      Finland        NaN  Lappeenranta
# abdelju01          USA         MI      Muskegon

# %%
scoring.head(2)
# Out:
#     playerID  year tmID    GP    G    A  Pts   SOG
# 0  aaltoan01  1997  ANA   3.0  0.0  0.0  0.0   1.0
# 1  aaltoan01  1998  ANA  73.0  3.0  5.0  8.0  61.0

# %%
pd.merge(master, scoring, right_on='playerID', left_index=True).head()
# Out:
#   firstName    lastName pos  birthYear  birthMon  birthDay birthCountry  \
# 0     Antti       Aalto   C     1975.0       3.0       4.0      Finland
# 1     Antti       Aalto   C     1975.0       3.0       4.0      Finland
# 2     Antti       Aalto   C     1975.0       3.0       4.0      Finland
# 3     Antti       Aalto   C     1975.0       3.0       4.0      Finland
# 4    Justin  Abdelkader   L     1987.0       2.0      25.0          USA
#
#   birthState     birthCity   playerID  year tmID    GP    G     A   Pts    SOG
# 0        NaN  Lappeenranta  aaltoan01  1997  ANA   3.0  0.0   0.0   0.0    1.0
# 1        NaN  Lappeenranta  aaltoan01  1998  ANA  73.0  3.0   5.0   8.0   61.0
# 2        NaN  Lappeenranta  aaltoan01  1999  ANA  63.0  7.0  11.0  18.0  102.0
# 3        NaN  Lappeenranta  aaltoan01  2000  ANA  12.0  1.0   1.0   2.0   18.0
# 4         MI      Muskegon  abdelju01  2007  DET   2.0  0.0   0.0   0.0    6.0

# %%
scoring.index
# Out:
# RangeIndex(start=0, stop=28616, step=1)

# %%
scoring.index = scoring.index + 3

# %%
scoring.index
# Out:
# RangeIndex(start=3, stop=28619, step=1)

# %%
pd.merge(master, scoring, right_on='playerID', left_index=True).head()
# Out:
#   firstName    lastName pos  birthYear  birthMon  birthDay birthCountry  \
# 3     Antti       Aalto   C     1975.0       3.0       4.0      Finland
# 4     Antti       Aalto   C     1975.0       3.0       4.0      Finland
# 5     Antti       Aalto   C     1975.0       3.0       4.0      Finland
# 6     Antti       Aalto   C     1975.0       3.0       4.0      Finland
# 7    Justin  Abdelkader   L     1987.0       2.0      25.0          USA
#
#   birthState     birthCity   playerID  year tmID    GP    G     A   Pts    SOG
# 3        NaN  Lappeenranta  aaltoan01  1997  ANA   3.0  0.0   0.0   0.0    1.0
# 4        NaN  Lappeenranta  aaltoan01  1998  ANA  73.0  3.0   5.0   8.0   61.0
# 5        NaN  Lappeenranta  aaltoan01  1999  ANA  63.0  7.0  11.0  18.0  102.0
# 6        NaN  Lappeenranta  aaltoan01  2000  ANA  12.0  1.0   1.0   2.0   18.0
# 7         MI      Muskegon  abdelju01  2007  DET   2.0  0.0   0.0   0.0    6.0

# %%
temp_df = pd.merge(master, scoring.set_index('playerID', drop=True), right_on='playerID', left_index=True).head()

# %%
temp_df
# Out:
#           firstName    lastName pos  birthYear  birthMon  birthDay  \
# playerID
# aaltoan01     Antti       Aalto   C     1975.0       3.0       4.0
# aaltoan01     Antti       Aalto   C     1975.0       3.0       4.0
# aaltoan01     Antti       Aalto   C     1975.0       3.0       4.0
# aaltoan01     Antti       Aalto   C     1975.0       3.0       4.0
# abdelju01    Justin  Abdelkader   L     1987.0       2.0      25.0
#
#           birthCountry birthState     birthCity  year tmID    GP    G     A  \
# playerID
# aaltoan01      Finland        NaN  Lappeenranta  1997  ANA   3.0  0.0   0.0
# aaltoan01      Finland        NaN  Lappeenranta  1998  ANA  73.0  3.0   5.0
# aaltoan01      Finland        NaN  Lappeenranta  1999  ANA  63.0  7.0  11.0
# aaltoan01      Finland        NaN  Lappeenranta  2000  ANA  12.0  1.0   1.0
# abdelju01          USA         MI      Muskegon  2007  DET   2.0  0.0   0.0
#
#             Pts    SOG
# playerID
# aaltoan01   0.0    1.0
# aaltoan01   8.0   61.0
# ...

# %%
temp_df.iloc[0, :]
# Out:
# firstName              Antti
# lastName               Aalto
# pos                        C
# birthYear             1975.0
# birthMon                 3.0
# birthDay                 4.0
# birthCountry         Finland
# birthState               NaN
# birthCity       Lappeenranta
# year                    1997
# tmID                     ANA
# GP                       3.0
# G                        0.0
# A                        0.0
# Pts                      0.0
# SOG                      1.0
# Name: aaltoan01, dtype: object

# %%
temp_df.loc['aaltoan01', :]
# Out:
#           firstName lastName pos  birthYear  birthMon  birthDay birthCountry  \
# playerID
# aaltoan01     Antti    Aalto   C     1975.0       3.0       4.0      Finland
# aaltoan01     Antti    Aalto   C     1975.0       3.0       4.0      Finland
# aaltoan01     Antti    Aalto   C     1975.0       3.0       4.0      Finland
# aaltoan01     Antti    Aalto   C     1975.0       3.0       4.0      Finland
#
#           birthState     birthCity  year tmID    GP    G     A   Pts    SOG
# playerID
# aaltoan01        NaN  Lappeenranta  1997  ANA   3.0  0.0   0.0   0.0    1.0
# aaltoan01        NaN  Lappeenranta  1998  ANA  73.0  3.0   5.0   8.0   61.0
# aaltoan01        NaN  Lappeenranta  1999  ANA  63.0  7.0  11.0  18.0  102.0
# aaltoan01        NaN  Lappeenranta  2000  ANA  12.0  1.0   1.0   2.0   18.0

# %%
master_c = master.drop(master.sample(5).index)

# %%
master_c.shape
# Out:
# (4622, 9)

# %%
pd.merge(master_c, scoring, left_index=True, right_on='playerID').shape
# Out:
# (28600, 17)

# %%
pd.merge(master_c, scoring, left_index=True, right_on='playerID', how='right').shape
# Out:
# (28616, 17)

# %%
merged = pd.merge(master_c, scoring, left_index=True, right_on='playerID', how='right', indicator=True)
merged.shape
# Out:
# (28616, 18)

# %%
merged.head()
# Out:
#   firstName    lastName pos  birthYear  birthMon  birthDay birthCountry  \
# 3     Antti       Aalto   C     1975.0       3.0       4.0      Finland
# 4     Antti       Aalto   C     1975.0       3.0       4.0      Finland
# 5     Antti       Aalto   C     1975.0       3.0       4.0      Finland
# 6     Antti       Aalto   C     1975.0       3.0       4.0      Finland
# 7    Justin  Abdelkader   L     1987.0       2.0      25.0          USA
#
#   birthState     birthCity   playerID  year tmID    GP    G     A   Pts  \
# 3        NaN  Lappeenranta  aaltoan01  1997  ANA   3.0  0.0   0.0   0.0
# 4        NaN  Lappeenranta  aaltoan01  1998  ANA  73.0  3.0   5.0   8.0
# 5        NaN  Lappeenranta  aaltoan01  1999  ANA  63.0  7.0  11.0  18.0
# 6        NaN  Lappeenranta  aaltoan01  2000  ANA  12.0  1.0   1.0   2.0
# 7         MI      Muskegon  abdelju01  2007  DET   2.0  0.0   0.0   0.0
#
#      SOG _merge
# 3    1.0   both
# 4   61.0   both
# 5  102.0   both
# 6   18.0   both
# ...

# %%
merged['_merge'].value_counts()
# Out:
# both          28600
# right_only       16
# left_only         0
# Name: _merge, dtype: int64

# %%
merged[merged['_merge'] == 'right_only'].head()
# Out:
#       firstName lastName  pos  birthYear  birthMon  birthDay birthCountry  \
# 766         NaN      NaN  NaN        NaN       NaN       NaN          NaN
# 767         NaN      NaN  NaN        NaN       NaN       NaN          NaN
# 768         NaN      NaN  NaN        NaN       NaN       NaN          NaN
# 769         NaN      NaN  NaN        NaN       NaN       NaN          NaN
# 13436       NaN      NaN  NaN        NaN       NaN       NaN          NaN
#
#       birthState birthCity   playerID  year tmID    GP     G     A   Pts  \
# 766          NaN       NaN  backlmi01  2008  CAL   1.0   0.0   0.0   0.0
# 767          NaN       NaN  backlmi01  2009  CAL  23.0   1.0   9.0  10.0
# 768          NaN       NaN  backlmi01  2010  CAL  73.0  10.0  15.0  25.0
# 769          NaN       NaN  backlmi01  2011  CAL  41.0   4.0   7.0  11.0
# 13436        NaN       NaN  labreyv01  1980  WAS  25.0   2.0   4.0   6.0
#
#          SOG      _merge
# 766      1.0  right_only
# 767     47.0  right_only
# ...

# %%
scoring_c = scoring.drop(scoring.sample(1000).index)

# %%
merged = pd.merge(master_c, scoring_c, left_index=True, right_on='playerID', how='outer', indicator=True)

# %%
merged.shape
# Out:
# (27647, 18)

# %%
merged[(merged['_merge'] == 'left_only') | (merged['_merge'] == 'right_only')].sample(3)
# Out:
#         firstName lastName  pos  birthYear  birthMon  birthDay birthCountry  \
# 23374.0       NaN      NaN  NaN        NaN       NaN       NaN          NaN
# 28181.0       NaN      NaN  NaN        NaN       NaN       NaN          NaN
# 23375.0       NaN      NaN  NaN        NaN       NaN       NaN          NaN
#
#         birthState birthCity   playerID    year tmID    GP    G     A   Pts  \
# 23374.0        NaN       NaN  shaunsc01  1986.0  QUE   3.0  0.0   0.0   0.0
# 28181.0        NaN       NaN  yloneju01  1998.0  PHO  59.0  6.0  17.0  23.0
# 23375.0        NaN       NaN  shaunsc01  1988.0  QUE   4.0  0.0   0.0   0.0
#
#           SOG      _merge
# 23374.0   0.0  right_only
# 28181.0  66.0  right_only
# 23375.0   0.0  right_only

# %%
merged[merged['_merge'].str.endswith('only')].sample(5)
# Out:
#         firstName  lastName  pos  birthYear  birthMon  birthDay birthCountry  \
# NaN        Alexei  Vasiliev    D     1977.0       9.0       1.0       Russia
# 767.0         NaN       NaN  NaN        NaN       NaN       NaN          NaN
# NaN         Jarod    Palmer    R     1986.0       2.0      10.0          NaN
# 27537.0       NaN       NaN  NaN        NaN       NaN       NaN          NaN
# NaN           Bob    Wilkie    D     1969.0       2.0      11.0       Canada
#
#         birthState  birthCity   playerID    year tmID    GP    G    A   Pts  \
# NaN            NaN  Yaroslavl  vasilal02     NaN  NaN   NaN  NaN  NaN   NaN
# 767.0          NaN        NaN  backlmi01  2009.0  CAL  23.0  1.0  9.0  10.0
# NaN            NaN        NaN  palmeja01     NaN  NaN   NaN  NaN  NaN   NaN
# 27537.0        NaN        NaN  whistro01  1987.0  STL  19.0  3.0  3.0   6.0
# NaN             AB    Calgary  wilkibo01     NaN  NaN   NaN  NaN  NaN   NaN
#
#           SOG      _merge
# ...

# %%
pd.merge(master, scoring, left_index=True, right_on='playerID', how='outer', indicator=True, validate='1:m').shape
# Out:
# (28616, 18)

# %%
try: 
    pd.merge(master, scoring, left_index=True, right_on='playerID', how='outer', indicator=True, validate='1:1')

except MergeError as e:
    print(e)
# Out:
# Merge keys are not unique in right dataset; not a one-to-one merge

# %%
scoring.index
# Out:
# RangeIndex(start=3, stop=28619, step=1)

# %%
scoring.reset_index(drop=True, inplace=True)

# %%
scoring.index
# Out:
# RangeIndex(start=0, stop=28616, step=1)

# %%
merged = pd.merge(master, scoring, left_index=True, right_on='playerID')
merged.head()
# Out:
#   firstName    lastName pos  birthYear  birthMon  birthDay birthCountry  \
# 0     Antti       Aalto   C     1975.0       3.0       4.0      Finland
# 1     Antti       Aalto   C     1975.0       3.0       4.0      Finland
# 2     Antti       Aalto   C     1975.0       3.0       4.0      Finland
# 3     Antti       Aalto   C     1975.0       3.0       4.0      Finland
# 4    Justin  Abdelkader   L     1987.0       2.0      25.0          USA
#
#   birthState     birthCity   playerID  year tmID    GP    G     A   Pts    SOG
# 0        NaN  Lappeenranta  aaltoan01  1997  ANA   3.0  0.0   0.0   0.0    1.0
# 1        NaN  Lappeenranta  aaltoan01  1998  ANA  73.0  3.0   5.0   8.0   61.0
# 2        NaN  Lappeenranta  aaltoan01  1999  ANA  63.0  7.0  11.0  18.0  102.0
# 3        NaN  Lappeenranta  aaltoan01  2000  ANA  12.0  1.0   1.0   2.0   18.0
# 4         MI      Muskegon  abdelju01  2007  DET   2.0  0.0   0.0   0.0    6.0

# %%
merged.filter(regex='^(?!(birth)).*')
# Out:
#       firstName    lastName pos   playerID  year tmID    GP    G     A   Pts  \
# 0         Antti       Aalto   C  aaltoan01  1997  ANA   3.0  0.0   0.0   0.0
# 1         Antti       Aalto   C  aaltoan01  1998  ANA  73.0  3.0   5.0   8.0
# 2         Antti       Aalto   C  aaltoan01  1999  ANA  63.0  7.0  11.0  18.0
# 3         Antti       Aalto   C  aaltoan01  2000  ANA  12.0  1.0   1.0   2.0
# 4        Justin  Abdelkader   L  abdelju01  2007  DET   2.0  0.0   0.0   0.0
# ...         ...         ...  ..        ...   ...  ...   ...  ...   ...   ...
# 28611    Andrei      Zyuzin   D  zyuzian01  2002  MIN  66.0  4.0  12.0  16.0
# 28612    Andrei      Zyuzin   D  zyuzian01  2003  MIN  65.0  8.0  13.0  21.0
# 28613    Andrei      Zyuzin   D  zyuzian01  2005  MIN  57.0  7.0  11.0  18.0
# 28614    Andrei      Zyuzin   D  zyuzian01  2006  CAL  49.0  1.0   5.0   6.0
# 28615    Andrei      Zyuzin   D  zyuzian01  2007  CHI  32.0  2.0   3.0   5.0
#
#          SOG
# 0        1.0
# 1       61.0
# ...

# %%
merged.to_pickle(os.path.join('dataset01', 'scoring_merged.pickle'))

# %% [markdown]
# ---

# %%
teams2 = teams[['tmID', 'name']]
teams2.head()
# Out:
#     tmID                 name
# 727  BOS        Boston Bruins
# 728  BUF       Buffalo Sabres
# 729  CAL       Calgary Flames
# 730  CHI  Chicago Black Hawks
# 731  COR     Colorado Rockies

# %%
teams2.shape
# Out:
# (792, 2)

# %%
teams2.drop_duplicates().shape
# Out:
# (38, 2)

# %%
teams2 = teams2.drop_duplicates()

# %%
teams2['tmID'].value_counts()
# Out:
# CHI    2
# ANA    1
# QUE    1
# NJD    1
# NYI    1
# NYR    1
# OTT    1
# PHI    1
# PHO    1
# PIT    1
# SJS    1
# MTL    1
# STL    1
# TBL    1
# TOR    1
# VAN    1
# WAS    1
# WIN    1
# NAS    1
# MNS    1
# AND    1
# COL    1
# ATL    1
# BOS    1
# BUF    1
# CAL    1
# CAR    1
# CBS    1
# COR    1
# MIN    1
# DAL    1
# DET    1
# EDM    1
# FLO    1
# HAR    1
# LAK    1
# WPG    1
# Name: tmID, dtype: int64

# %%
teams2.loc[teams2['tmID'] == 'CHI']
# Out:
#     tmID                 name
# 730  CHI  Chicago Black Hawks
# 856  CHI   Chicago Blackhawks

# %%
teams2 = teams2[teams2['tmID'] == 'CHI']

# %%
team_splits2 = team_splits[team_splits['tmID'] == 'CHI'].sample(2)
team_splits2
# Out:
#       year tmID  SepW  SepL  SepT  SepOL  OctW  OctL  OctT  OctOL  ...  FebT  \
# 1008  1993  CHI   NaN   NaN   NaN    NaN   4.0   7.0   2.0    NaN  ...   1.0
# 1346  2006  CHI   NaN   NaN   NaN    NaN   4.0   8.0   NaN    0.0  ...   NaN
#
#       FebOL  MarW  MarL  MarT  MarOL  AprW  AprL  AprT  AprOL
# 1008    NaN   6.0   7.0   2.0    NaN   4.0   2.0   0.0    NaN
# 1346    2.0   5.0   9.0   NaN    0.0   3.0   2.0   NaN    0.0
#
# [2 rows x 34 columns]

# %%
pd.merge(teams2, team_splits2)
# Out:
#   tmID                 name  year  SepW  SepL  SepT  SepOL  OctW  OctL  OctT  \
# 0  CHI  Chicago Black Hawks  1993   NaN   NaN   NaN    NaN   4.0   7.0   2.0
# 1  CHI  Chicago Black Hawks  2006   NaN   NaN   NaN    NaN   4.0   8.0   NaN
# 2  CHI   Chicago Blackhawks  1993   NaN   NaN   NaN    NaN   4.0   7.0   2.0
# 3  CHI   Chicago Blackhawks  2006   NaN   NaN   NaN    NaN   4.0   8.0   NaN
#
#    ...  FebT  FebOL  MarW  MarL  MarT  MarOL  AprW  AprL  AprT  AprOL
# 0  ...   1.0    NaN   6.0   7.0   2.0    NaN   4.0   2.0   0.0    NaN
# 1  ...   NaN    2.0   5.0   9.0   NaN    0.0   3.0   2.0   NaN    0.0
# 2  ...   1.0    NaN   6.0   7.0   2.0    NaN   4.0   2.0   0.0    NaN
# 3  ...   NaN    2.0   5.0   9.0   NaN    0.0   3.0   2.0   NaN    0.0
#
# [4 rows x 35 columns]

# %%
pd.merge(team_splits, teams).shape
# Out:
# (792, 35)

# %%
pd.merge(team_splits, teams, left_on=['tmID', 'year'], right_on=['tmID', 'year']).shape
# Out:
# (792, 35)

# %%
pd.merge(team_splits, teams, on=['tmID', 'year']).head(2)
# Out:
#    year tmID  SepW  SepL  SepT  SepOL  OctW  OctL  OctT  OctOL  ...  FebOL  \
# 0  1980  BOS   NaN   NaN   NaN    NaN   2.0   7.0   1.0    NaN  ...    NaN
# 1  1980  BUF   NaN   NaN   NaN    NaN   5.0   2.0   2.0    NaN  ...    NaN
#
#    MarW  MarL  MarT  MarOL  AprW  AprL  AprT  AprOL            name
# 0   8.0   4.0   3.0    NaN   1.0   2.0   0.0    NaN   Boston Bruins
# 1   8.0   6.0   1.0    NaN   1.0   1.0   1.0    NaN  Buffalo Sabres
#
# [2 rows x 35 columns]

# %%
pd.merge(team_splits, teams, on=['tmID']).head(2)
# Out:
#    year_x tmID  SepW  SepL  SepT  SepOL  OctW  OctL  OctT  OctOL  ...  MarW  \
# 0    1980  BOS   NaN   NaN   NaN    NaN   2.0   7.0   1.0    NaN  ...   8.0
# 1    1980  BOS   NaN   NaN   NaN    NaN   2.0   7.0   1.0    NaN  ...   8.0
#
#    MarL  MarT  MarOL  AprW  AprL  AprT  AprOL  year_y           name
# 0   4.0   3.0    NaN   1.0   2.0   0.0    NaN    1980  Boston Bruins
# 1   4.0   3.0    NaN   1.0   2.0   0.0    NaN    1981  Boston Bruins
#
# [2 rows x 36 columns]

# %%
pd.merge(team_splits, teams, on=['tmID']).head(5).filter(like='year')
# Out:
#    year_x  year_y
# 0    1980    1980
# 1    1980    1981
# 2    1980    1982
# 3    1980    1983
# 4    1980    1984

# %%
pd.merge(team_splits, teams, suffixes=['_team_splits', '_teams'],  on=['tmID']).head(5).filter(like='year')
# Out:
#    year_team_splits  year_teams
# 0              1980        1980
# 1              1980        1981
# 2              1980        1982
# 3              1980        1983
# 4              1980        1984

# %%
merged = pd.merge(team_splits, teams, on=['tmID', 'year'])
merged.head(3)
# Out:
#    year tmID  SepW  SepL  SepT  SepOL  OctW  OctL  OctT  OctOL  ...  FebOL  \
# 0  1980  BOS   NaN   NaN   NaN    NaN   2.0   7.0   1.0    NaN  ...    NaN
# 1  1980  BUF   NaN   NaN   NaN    NaN   5.0   2.0   2.0    NaN  ...    NaN
# 2  1980  CAL   NaN   NaN   NaN    NaN   5.0   4.0   2.0    NaN  ...    NaN
#
#    MarW  MarL  MarT  MarOL  AprW  AprL  AprT  AprOL            name
# 0   8.0   4.0   3.0    NaN   1.0   2.0   0.0    NaN   Boston Bruins
# 1   8.0   6.0   1.0    NaN   1.0   1.0   1.0    NaN  Buffalo Sabres
# 2   6.0   6.0   2.0    NaN   2.0   0.0   0.0    NaN  Calgary Flames
#
# [3 rows x 35 columns]

# %%
merged.to_pickle(os.path.join('dataset01', 'team_splits_merged.pickle'))
