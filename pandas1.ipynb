# %%
import os
import pandas as pd

# %%
dataset_path = os.path.join('dataset01', 'artwork_data.csv')

# %%
df = pd.read_csv(dataset_path)
# Out:
# /tmp/ipykernel_7449/2793407076.py:1: DtypeWarning: Columns (9,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(dataset_path)

# %%
df
# Out:
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %%
df.shape
# Out:
# (69201, 20)

# %%
df.describe()
# Out:
#                   id      artistId  acquisitionYear         depth
# count   69201.000000  69201.000000     69156.000000   2514.000000
# mean    39148.026213   1201.063251      1910.646856    479.197772
# std     25980.468687   2019.422535        64.202148   1051.141734
# min         3.000000      0.000000      1823.000000      1.000000
# 25%     19096.000000    558.000000      1856.000000     48.250000
# 50%     37339.000000    558.000000      1856.000000    190.000000
# 75%     54712.000000   1137.000000      1982.000000    450.000000
# max    129068.000000  19232.000000      2013.000000  18290.000000

# %%
df = pd.read_csv(dataset_path, nrows=5)

# %%
df
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
df = pd.read_csv(dataset_path, nrows=5, index_col='id')

# %%
df
# Out:
#      accession_number          artist artistRole  artistId  \
# id
# 1035           A00001   Blake, Robert     artist        38
# 1036           A00002   Blake, Robert     artist        38
# 1037           A00003   Blake, Robert     artist        38
# 1038           A00004   Blake, Robert     artist        38
# 1039           A00005  Blake, William     artist        39
#
#                                                   title  \
# id
# 1035  A Figure Bowing before a Seated Old Man with h...
# 1036  Two Drawings of Frightened Figures, Probably f...
# 1037  The Preaching of Warning. Verso: An Old Man En...
# 1038     Six Drawings of Figures with Outstretched Arms
# 1039  The Circle of the Lustful: Francesca da Rimini...
#
#                     dateText  \
# id
# 1035          date not known
# 1036          date not known
# 1037                 ?c.1785
# 1038          date not known
# 1039  1826–7, reprinted 1892
#
#                                                  medium  \
# id
# ...

# %%
df = pd.read_csv(dataset_path, nrows=5, index_col='id', usecols=['id', 'artist'])
df
# Out:
#               artist
# id
# 1035   Blake, Robert
# 1036   Blake, Robert
# 1037   Blake, Robert
# 1038   Blake, Robert
# 1039  Blake, William

# %%
df = pd.read_csv(dataset_path, nrows=5, index_col='id')
df.columns
# Out:
# Index(['accession_number', 'artist', 'artistRole', 'artistId', 'title',
#        'dateText', 'medium', 'creditLine', 'year', 'acquisitionYear',
#        'dimensions', 'width', 'height', 'depth', 'units', 'inscription',
#        'thumbnailCopyright', 'thumbnailUrl', 'url'],
#       dtype='object')

# %%
df.to_pickle(os.path.join('dataset01', 'data_frame.pickle'))

# %%
import json

# %%
records = [('Audi', '500'), ('BMW', '45')]

# %%
pd.DataFrame.from_records(records)
# Out:
#       0    1
# 0  Audi  500
# 1   BMW   45

# %%
pd.DataFrame.from_records(records, columns=['Brand', 'Price'])
# Out:
#   Brand Price
# 0  Audi   500
# 1   BMW    45

# %%
json_path = os.path.join('dataset01', 'a00001-1035.json')

# %%
# df = pd.read_json(json_path)
# df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [30], line 1
# ----> 1 df = pd.read_json(json_path)
#       2 df
#
# File ~/projects/python_kings/data_science/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/projects/python_kings/data_science/lib/python3.10/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# ...

# %%
keys = ['id', 'all_artists', 'medium', 'dateText', 'acquisitionYear', 'height', 'width']

# %%
with open(json_path) as file:
    content = json.load(file)
    
record = []
    
for key in keys:
    record.append(content[key])
    
record
# Out:
# [1035,
#  'Robert Blake',
#  'Watercolour, ink, chalk and graphite on paper. Verso: graphite on paper',
#  'date not known',
#  1922,
#  '419',
#  '394']

# %%
pd.DataFrame.from_records([record], columns=keys)
# Out:
#      id   all_artists                                             medium  \
# 0  1035  Robert Blake  Watercolour, ink, chalk and graphite on paper....
#
#          dateText  acquisitionYear height width
# 0  date not known             1922    419   394

# %%
df = pd.read_csv(dataset_path)
# Out:
# /tmp/ipykernel_7449/2793407076.py:1: DtypeWarning: Columns (9,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(dataset_path)

# %%
df
# Out:
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %%
df.artist
# Out:
# 0             Blake, Robert
# 1             Blake, Robert
# 2             Blake, Robert
# 3             Blake, Robert
# 4            Blake, William
#                 ...
# 69196    P-Orridge, Genesis
# 69197    P-Orridge, Genesis
# 69198          Hatoum, Mona
# 69199         Creed, Martin
# 69200     Brunias, Agostino
# Name: artist, Length: 69201, dtype: object

# %%
df['artist'] # pewniejszy sposób!! bo np. mogą być spacje w nazwie
# Out:
# 0             Blake, Robert
# 1             Blake, Robert
# 2             Blake, Robert
# 3             Blake, Robert
# 4            Blake, William
#                 ...
# 69196    P-Orridge, Genesis
# 69197    P-Orridge, Genesis
# 69198          Hatoum, Mona
# 69199         Creed, Martin
# 69200     Brunias, Agostino
# Name: artist, Length: 69201, dtype: object

# %%
artists = df['artist']

# %%
artists
# Out:
# 0             Blake, Robert
# 1             Blake, Robert
# 2             Blake, Robert
# 3             Blake, Robert
# 4            Blake, William
#                 ...
# 69196    P-Orridge, Genesis
# 69197    P-Orridge, Genesis
# 69198          Hatoum, Mona
# 69199         Creed, Martin
# 69200     Brunias, Agostino
# Name: artist, Length: 69201, dtype: object

# %%
pd.unique(artists)
# Out:
# array(['Blake, Robert', 'Blake, William', 'Richmond, George', ...,
#        'Sterne, Hedda', 'P-Orridge, Genesis', 'Brunias, Agostino'],
#       dtype=object)

# %%
len(pd.unique(artists))
# Out:
# 3336

# %%
df[df['artist'] == 'Bacon, Francis']
# Out:
#           id accession_number          artist artistRole  artistId  \
# 44125    672           N05941  Bacon, Francis     artist       682
# 44242    673           N06131  Bacon, Francis     artist       682
# 44272    674           N06171  Bacon, Francis     artist       682
# 55811    677           T00226  Bacon, Francis     artist       682
# 56032    678           T00453  Bacon, Francis     artist       682
# 56038    679           T00459  Bacon, Francis     artist       682
# 56183    680           T00604  Bacon, Francis     artist       682
# 56456    681           T00879  Bacon, Francis     artist       682
# 57555    682           T02112  Bacon, Francis     artist       682
# 57854    683           T02414  Bacon, Francis     artist       682
# 58513    684           T03073  Bacon, Francis     artist       682
# 61285  19509           T05858  Bacon, Francis     artist       682
# 62761  26004           T07351  Bacon, Francis     artist       682
# ...

# %%
s = df['artist'] == 'Bacon, Francis'

# %%
type(s)
# kolumna jest serią!! dodaje funkcjonalności do np.array
# Out:
# pandas.core.series.Series

# %%
s.value_counts()
# Out:
# False    69151
# True        50
# Name: artist, dtype: int64

# %%
artist_count = df['artist'].value_counts()

# %%
artist_count
# Out:
# Turner, Joseph Mallord William    39389
# Jones, George                      1046
# Moore, Henry, OM, CH                623
# Daniell, William                    612
# Beuys, Joseph                       578
#                                   ...
# Torner, Gustavo                       1
# Casas, Juan Vila                      1
# Fussell, Michael                      1
# Lucio                                 1
# Brunias, Agostino                     1
# Name: artist, Length: 3336, dtype: int64

# %%
artist_count['Bacon, Francis']
# Out:
# 50

# %%
df.loc[1035] # jedna obserwacja
# Out:
# id                                                                  851
# accession_number                                                 A01039
# artist                                                Beerbohm, Sir Max
# artistRole                                                       artist
# artistId                                                            722
# title                         British Stock and Alien Inspiration, 1849
# dateText                                                           1917
# medium                                Graphite and watercolour on paper
# creditLine                          Bequeathed by Sir Hugh Walpole 1941
# year                                                             1917.0
# acquisitionYear                                                  1941.0
# dimensions                                        support: 298 x 419 mm
# width                                                               298
# ...

# %%
df.loc[1035, 'artist']
# Out:
# 'Beerbohm, Sir Max'

# %%
df.iloc[0, 0] # pierwszy wiersz, pierwsza kolumna - inaczej niż w NumPy!
# Out:
# 1035

# %%
df.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
df.iloc[0, :] # pierwszy wiersz
# Out:
# id                                                                 1035
# accession_number                                                 A00001
# artist                                                    Blake, Robert
# artistRole                                                       artist
# artistId                                                             38
# title                 A Figure Bowing before a Seated Old Man with h...
# dateText                                                 date not known
# medium                Watercolour, ink, chalk and graphite on paper....
# creditLine                          Presented by Mrs John Richmond 1922
# year                                                                NaN
# acquisitionYear                                                  1922.0
# dimensions                                        support: 394 x 419 mm
# width                                                               394
# ...

# %%
df.iloc[0:2, 0:2] # to jest lepsze niż następne
# Out:
#      id accession_number
# 0  1035           A00001
# 1  1036           A00002

# %%
df.iloc[[0,1],[0,1]]
# Out:
#      id accession_number
# 0  1035           A00001
# 1  1036           A00002

# %%
# df['height'] * df['width']
df['width'].sort_values().head()
# Out:
# 62198           (1):
# 68540    (diameter):
# 2427         (each):
# 54196        (each):
# 67796       (image):
# Name: width, dtype: object

# %%
pd.to_numeric(df['width'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/projects/python_kings/data_science/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2364, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "(upper):"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In [69], line 1
# ----> 1 pd.to_numeric(df['width'])
#
# File ~/projects/python_kings/data_science/lib/python3.10/site-packages/pandas/core/tools/numeric.py:185, in to_numeric(arg, errors, downcast)
#     183 coerce_numeric = errors not in ("ignore", "raise")
#     184 try:
# --> 185     values, _ = lib.maybe_convert_numeric(
#     186         values, set(), coerce_numeric=coerce_numeric
#     187     )
#     188 except (ValueError, TypeError):
#     189     if errors == "raise":
#
# ...

# %%
pd.to_numeric(df['width'], errors='coerce')
# Out:
# 0        394.0
# 1        311.0
# 2        343.0
# 3        318.0
# 4        243.0
#          ...
# 69196    305.0
# 69197    305.0
# 69198     45.0
# 69199      NaN
# 69200    508.0
# Name: width, Length: 69201, dtype: float64

# %%
df.loc[:, 'width'] = pd.to_numeric(df['width'], errors='coerce')
# Out:
# /tmp/ipykernel_7449/3359077335.py:1: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'width'] = pd.to_numeric(df['width'], errors='coerce')

# %%
df.loc[:, 'height'] = pd.to_numeric(df['height'], errors='coerce')
# Out:
# /tmp/ipykernel_7449/3067616293.py:1: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'height'] = pd.to_numeric(df['height'], errors='coerce')

# %%
area = df['height'] * df['width']

# %%
df = df.assign(area=area)
df.head()
df.columns
# Out:
# Index(['id', 'accession_number', 'artist', 'artistRole', 'artistId', 'title',
#        'dateText', 'medium', 'creditLine', 'year', 'acquisitionYear',
#        'dimensions', 'width', 'height', 'depth', 'units', 'inscription',
#        'thumbnailCopyright', 'thumbnailUrl', 'url', 'area'],
#       dtype='object')

# %%
df['area'].max()
# Out:
# 132462000.0

# %%
df['area'].idxmax() # id elementu z max value
# Out:
# 1903

# %%
df.loc[df['area'].idxmax(), :]
# Out:
# id                                                                98367
# accession_number                                                AR00166
# artist                                                 Therrien, Robert
# artistRole                                                       artist
# artistId                                                           2312
# title                                  No Title (Table and Four Chairs)
# dateText                                                           2003
# medium                               Aluminium, steel, wood and plastic
# creditLine            ARTIST ROOMS Acquired jointly with the Nationa...
# year                                                             2003.0
# acquisitionYear                                                  2008.0
# dimensions            displayed: 8920 x 14850 mm object, each (Chair...
# width                                                            8920.0
# ...

# %%
df.shape
# Out:
# (69201, 21)

# %%
sm_df = df.iloc[49980:50019, :].copy()
sm_df
# Out:
#           id accession_number             artist artistRole  artistId  \
# 49980  16412           P07951               Wols     artist      2164
# 49981  16413           P07952               Wols     artist      2164
# 49982  16414           P07953               Wols     artist      2164
# 49983  16415           P07954               Wols     artist      2164
# 49984  16416           P07955               Wols     artist      2164
# 49985  16417           P07956               Wols     artist      2164
# 49986  16418           P07957               Wols     artist      2164
# 49987  16419           P07958               Wols     artist      2164
# 49988  16420           P07959               Wols     artist      2164
# 49989  16421           P07960               Wols     artist      2164
# 49990  16422           P07961               Wols     artist      2164
# 49991  16423           P07962               Wols     artist      2164
# ...

# %%
grouped = sm_df.groupby('artist')

# %%
grouped

# %%
for name, group_df in grouped:
    print(name)
    print(group_df)
# Out:
# Frost, Sir Terry
#          id accession_number            artist artistRole  artistId  \
# 50010  4704           P07981  Frost, Sir Terry     artist      1126
# 50011  4705           P07982  Frost, Sir Terry     artist      1126
# 50012  4706           P07983  Frost, Sir Terry     artist      1126
# 50013  4707           P07984  Frost, Sir Terry     artist      1126
# 50014  4708           P07985  Frost, Sir Terry     artist      1126
# 50015  4709           P07986  Frost, Sir Terry     artist      1126
# 50016  4710           P07987  Frost, Sir Terry     artist      1126
# 50017  4711           P07988  Frost, Sir Terry     artist      1126
#
#                  title dateText               medium      creditLine    year  \
# 50010        Blue Moon     1952  Lithograph on paper  Purchased 1983  1952.0
# 50011      Boat Shapes     1952     Linocut on paper  Purchased 1983  1952.0
# 50012      Boat Shapes   c.1954     Linocut on paper  Purchased 1983  1954.0
# ...

# %%
for name, group_df in grouped:
    print(name)
    print(group_df['acquisitionYear'].min())
    print('-'*30)
# Out:
# Frost, Sir Terry
# 1983.0
# ------------------------------
# Phillips, Esq Tom
# 1983.0
# ------------------------------
# Wols
# 1983.0
# ------------------------------

# %%
sm_df.groupby('artist')['acquisitionYear'].min()
# Out:
# artist
# Frost, Sir Terry     1983.0
# Phillips, Esq Tom    1983.0
# Wols                 1983.0
# Name: acquisitionYear, dtype: float64
